# %% [markdown]
# # Lab | Intro to Probability

# %% [markdown]
# **Objective**
#
# Welcome to this Intro to Probability lab, where we explore decision-making scenarios through the lens of probability and strategic analysis. In the business world, making informed decisions is crucial, especially when faced with uncertainties. This lab focuses on scenarios where probabilistic outcomes play a significant role in shaping strategies and outcomes. Students will engage in exercises that require assessing and choosing optimal paths based on data-driven insights. The goal is to enhance your skills by applying probability concepts to solve real-world problems.

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# #### Ironhack Airlines
#
# Often Airlines sell more tickets than they have seats available, this is called overbooking. Consider the following:
# - A plane has 450 seats.
# - Based on historical data we conclude that each individual passenger has a 3% chance of missing it's flight.
#
# If the Ironhack Airlines routinely sells 460 tickets, what is the chance that they have a seats for all passenger?

# %%
# Binomial distribution

from scipy.stats import binom

n = 460      # number of ticket holders
p = 0.97     # probability of showing up

prob = binom.cdf(450, n, p)
print(f"Probability that 450 or fewer passengers show up: {prob:.5f}")

# There is a 88,4 % chance that Ironhack Airlines will have a seat for each passenger. I would not like to be in that 11,6 %
# Out:
# Probability that 450 or fewer passengers show up: 0.88448

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# #### Ironhack Call Center

# %% [markdown]
# Suppose a customer service representative at a call center is handling customer complaints. Consider the following:
# - The probability of successfully resolving a customer complaint on the first attempt is 0.3.
#
#
# What is the probability that the representative needs to make at least three attempts before successfully resolving a customer complaint?

# %%
# Geometric distribution

from scipy.stats import geom

p = 0.3
geom_dist = geom(p)

# P(success on 1st or 2nd try)
prob_under_3 = geom_dist.pmf(1) + geom_dist.pmf(2)

# So P(at least 3 attempts)
prob_at_least_3 = 1 - prob_under_3

print(f"Probability that at least 3 attempts are needed: {prob_at_least_3:.5f}")
# Out:
# Probability that at least 3 attempts are needed: 0.49000

# %% [markdown]
# **Challenge 3**

# %% [markdown]
# #### Ironhack Website

# %% [markdown]
# Consider a scenario related to Ironhack website traffic. Where:
# - our website takes on average 500 visits per hour.
# - the website's server is designed to handle up to 550 vists per hour.
#
#
# What is the probability of the website server being overwhelmed?

# %%
# Poisson 
from scipy.stats import poisson

# CDF gives P(X ≤ 550), so subtract from 1 for P(X > 550)
prob_overwhelmed = 1 - poisson_dist.cdf(550)

print(f"The probability of the server being overwhelmed is {prob_overwhelmed:f}")
# Out:
# The probability of the server being overwhelmed is 0.012898

# %% [markdown]
# What is the probability of being overwhelmed at some point during a day? (consider 24hours)

# %%
# Consider 24 'chances' of being overwhelmed 

mu = 500
limit = 550

# Probability of being overwhelmed in 1 hour
p_overwhelmed_hour = 1 - poisson.cdf(limit, mu)

# Probability of at least one overwhelmed hour in 24 hours
p_overwhelmed_day = 1 - (1 - p_overwhelmed_hour) ** 24

print(f"Probability of being overwhelmed at least once during a day: {p_overwhelmed_day:f}")
# Out:
# Probability of being overwhelmed at least once during a day: 0.267704

# %% [markdown]
# **Challenge 4**

# %% [markdown]
# #### Ironhack Helpdesk

# %% [markdown]
# Consider a scenario related to the time between arrivals of customers at a service desk.
#
# On average, a customers arrives every 10minutes.
#
# What is the probability that the next customer will arrive within the next 5 minutes?

# %%
# Exponential Distribution

from scipy.stats import expon

#the parameter represents the rate of events occuring per unit of time
lambda_value = 0.1 # per minute

lambda_inv = expon(scale = 1/lambda_value)

# Probability that next customer arrives within 5 minutes
prob_within_5 = lambda_inv.cdf(5)

print(f"Probability that the next customer arrives within 5 minutes: {prob_within_5:f}")
# Out:
# Probability that the next customer arrives within 5 minutes: 0.393469

# %% [markdown]
# If there is no customer for 15minutes, employees can that a 5minutes break.
#
# What is the probability an employee taking a break?

# %%
lambda_value = 0.1 # per minute

lambda_inv = expon(scale = 1/lambda_value)

# Probability that noone arrives within 15 minutes
prob_none_15 = 1 - lambda_inv.cdf(15)

print(f"Probability that noone arrives within 15 minutes: {prob_none_15:f}")
# Out:
# Probability that the next customer arrives within 5 minutes: 0.223130

# %% [markdown]
# **Challenge 5**

# %% [markdown]
# The weights of a certain species of birds follow a normal distribution with a mean weight of 150 grams and a standard deviation of 10 grams.
#
# - If we randomly select a bird, what is the probability that its weight is between 140 and 160 grams?

# %%
# Normal (Gaussian) Distribution

from scipy.stats import norm

mean = 150
std = 10

norm_dist = norm(loc = mean, scale = std)

prob_140_160 = norm_dist.cdf(160) - norm_dist.cdf(140)

print(f"The probability of a bird being between 140 and 160 grams is {prob_140_160:.4f}")
# Out:
# The probability of a bird being between 140 and 160 grams is 0.6827

# %% [markdown]
# **Challenge 6**

# %% [markdown]
# If the lifetime (in hours) of a certain electronic component follows an exponential distribution with a mean lifetime of 50 hours, what is the probability that the component fails within the first 30 hours?

# %%
# Exponential Distribution

from scipy.stats import expon

#the parameter represents the rate of events occuring per unit of time
lambda_value = 0.02

lambda_inv = expon(scale = 1/lambda_value)

prob_failure_30 = lambda_inv.cdf(30)

print(f"The probability of the component failing within the first 30 hours is {prob_failure_30}")
# Out:
# The probability of the component failing within the first 30 hours is 0.4511883639059736
